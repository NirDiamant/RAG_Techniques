# %% [markdown]
# # Recuperação Explicável na Pesquisa de Documentos
# ## Visão Geral
# Este código implementa um Retriever Explicável, um sistema que não só recupera documentos relevantes com base em uma consulta, mas também fornece explicações para o porquê de cada documento recuperado ser relevante. Combina pesquisa de similaridade baseada em vetores com explicações de linguagem natural, aumentando a transparência e interpretabilidade do processo de recuperação.
#
# ## Motivação
# Os sistemas tradicionais de recuperação de documentos muitas vezes funcionam como caixas pretas, fornecendo resultados sem explicar por que foram escolhidos. Essa falta de transparência pode ser problemática em cenários em que a compreensão do raciocínio por trás dos resultados é crucial. O Explicável Retriever aborda isso oferecendo insights sobre a relevância de cada documento recuperado.
#
# ## Componentes-chave
#
# 1. Criação de armazenamento de vetor a partir de textos de entrada
# 2. Recuperador base usando FAISS para pesquisa de similaridade eficiente
# 3. Modelo de linguagem (LLM) para geração de explicações
# 4. Custom ExplicávelRetriever classe que combina recuperação e geração de explicação
#
# ## Detalhes do método
# ## Pré-processamento de documentos e criação de Vector Store
#
# 1. Textos de entrada são convertidos em incorporações usando o modelo de incorporação do OpenAI.
# 2. Uma vector store FAISS é criada a partir desses embeddings para uma busca eficiente de similaridade.
#
# Configuração do retriever
#
# 1. Um retriever base é criado a partir da vector store, configurado para retornar os 5 documentos mais similares.
#
# Geração de Explicação
#
# 1. Um LLM (GPT-4) é usado para gerar explicações.
# 2. Um modelo de prompt personalizado é definido para orientar o LLM na explicação da relevância dos documentos recuperados.
#
# - ExplicableRetriever Classe
#
# 1. Combina o retriever base e geração de explicação em uma única interface.
# 2. O método `retrieve_and_explain`:
# - Recupera documentos relevantes usando o retriever base.
# - Para cada documento recuperado, gera uma explicação da sua relevância para a consulta.
# - Retorna uma lista de dicionários contendo o conteúdo do documento e sua explicação.
#
# ## Benefícios desta abordagem
# 1. Transparência: Os usuários podem entender por que documentos específicos foram recuperados.
# 2. Confiança: Explicações criam confiança do usuário nos resultados do sistema.
# 3. Aprendizagem: Os usuários podem obter insights sobre as relações entre consultas e documentos.
# 4. Depuração: É mais fácil identificar e corrigir problemas no processo de recuperação.
# 5. Personalização: O prompt de explicação pode ser adaptado para diferentes casos de uso ou domínios.
#
# ## Conclusão
# O Explicável Retriever representa um passo significativo para sistemas de recuperação de informações mais interpretáveis e confiáveis. Ao fornecer explicações de linguagem natural ao lado de documentos recuperados, ele une a lacuna entre poderosas técnicas de busca baseadas em vetores e compreensão humana. Essa abordagem tem aplicações potenciais em vários campos, onde o raciocínio por trás da recuperação de informações é tão importante quanto a própria informação recuperada, como pesquisa jurídica, sistemas de informação médica e ferramentas educacionais.

# %% [markdown]
# # Instalação e Importações do Pacote
# A célula abaixo instala todos os pacotes necessários para executar este notebook.
# .

# %%
# Install required packages
# !pip install python-dotenv

# %%
# Clone the repository to access helper functions and evaluation modules
# !git clone https://github.com/NirDiamant/RAG_TECHNIQUES.git
import sys
sys.path.append('RAG_TECHNIQUES')
# If you need to run with the latest data
# !cp -r RAG_TECHNIQUES/data .

# %%
import os
import sys
from dotenv import load_dotenv


# Original path append replaced for Colab compatibility
from helper_functions import *
from evaluation.evalute_rag import *

# Load environment variables from a .env file
load_dotenv()

# Set the OpenAI API key environment variable
os.environ["OPENAI_API_KEY"] = os.getenv('OPENAI_API_KEY')

# %% [markdown]
# ### Definir a classe de recuperação explicável

# %%
class ExplainableRetriever:
    def __init__(self, texts):
        self.embeddings = OpenAIEmbeddings()

        self.vectorstore = FAISS.from_texts(texts, self.embeddings)
        self.llm = ChatOpenAI(temperature=0, model_name="gpt-4o-mini", max_tokens=4000)

        
        # Create a base retriever
        self.retriever = self.vectorstore.as_retriever(search_kwargs={"k": 5})
        
        # Create an explanation chain
        explain_prompt = PromptTemplate(
            input_variables=["query", "context"],
            template="""
            Analyze the relationship between the following query and the retrieved context.
            Explain why this context is relevant to the query and how it might help answer the query.
            
            Query: {query}
            
            Context: {context}
            
            Explanation:
            """
        )
        self.explain_chain = explain_prompt | self.llm

    def retrieve_and_explain(self, query):
        # Retrieve relevant documents
        docs = self.retriever.get_relevant_documents(query)
        
        explained_results = []
        
        for doc in docs:
            # Generate explanation
            input_data = {"query": query, "context": doc.page_content}
            explanation = self.explain_chain.invoke(input_data).content
            
            explained_results.append({
                "content": doc.page_content,
                "explanation": explanation
            })
        
        return explained_results

# %% [markdown]
# ### Criar um exemplo simulado e uma instância de recuperação explicável

# %%
# Usage
texts = [
    "The sky is blue because of the way sunlight interacts with the atmosphere.",
    "Photosynthesis is the process by which plants use sunlight to produce energy.",
    "Global warming is caused by the increase of greenhouse gases in Earth's atmosphere."
]

explainable_retriever = ExplainableRetriever(texts)

# %% [markdown]
# ### Mostrar os resultados

# %%
query = "Why is the sky blue?"
results = explainable_retriever.retrieve_and_explain(query)

for i, result in enumerate(results, 1):
    print(f"Result {i}:")
    print(f"Content: {result['content']}")
    print(f"Explanation: {result['explanation']}")
    print()

# %% [markdown]
# ![](https://europe-west1-rag-techniques-views-tracker.cloudfunctions.net/rag-techniques-tracker?notebook=all-rag-techniques--explainable-retrieval)
