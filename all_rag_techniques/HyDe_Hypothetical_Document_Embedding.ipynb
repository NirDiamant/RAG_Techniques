# %% [markdown]
# # Embutimento de Documentos Hipotéticos (HyDE) em Recuperação de Documentos
# ## Visão Geral
# Este código implementa um sistema de Embutimento de Documentos Hipotéticos (HyDE) para recuperação de documentos. HyDE é uma abordagem inovadora que transforma as questões de consulta em documentos hipotéticos contendo a resposta, com o objetivo de preencher a lacuna entre as distribuições de consulta e documento no espaço vetorial.
#
# ## Motivação
# Os métodos tradicionais de recuperação muitas vezes lutam com a lacuna semântica entre consultas curtas e documentos mais detalhados. HyDE aborda isso expandindo a consulta em um documento hipotético completo, potencialmente melhorando a relevância da recuperação, tornando a representação da consulta mais semelhante às representações do documento no espaço vetorial.
#
# ## Componentes-chave
#
# 1. Processamento e chunks de texto PDF
# 2. Criação de armazenamento de vetores usando incorporações FAISS e OpenAI
# 3. Modelo de linguagem para geração de documentos hipotéticos
# 4. Classe personalizada HyDERetriever implementando a técnica HyDE
#
# ## Detalhes do método
# ## Pré-processamento de documentos e criação de Vector Store
#
# 1. O PDF é processado e dividido em chunks.
# 2. Uma vector store FAISS é criada usando embeddings da OpenAI para pesquisa de similaridade eficiente.
#
# Geração de Documentos Hipotéticos
#
# 1. Um modelo de linguagem (GPT-4) é usado para gerar um documento hipotético que responde à consulta dada.
# 2. A geração é guiada por um modelo prompt que garante que o documento hipotético é detalhado e corresponde ao tamanho do bloco usado na vector store.
#
# Processo de recuperação
#
# A classe `HyDERetriever` implementa os seguintes passos:
#
# 1. Gere um documento hipotético da consulta usando o modelo de linguagem.
# 2. Use o documento hipotético como a pesquisa na vector store.
# 3. Recuperar os documentos mais semelhantes a este documento hipotético.
#
# ## Características Principais
#
# 1. Expansão de Consulta: Transforma consultas curtas em documentos hipotéticos detalhados.
# 2. Configuração flexível: Permite o ajuste do tamanho do bloco, sobreposição e número de documentos recuperados.
# 3. Integração com OpenAI Modelos: Utiliza GPT-4 para geração de documentos hipotéticos e embeddings da OpenAI para representação vetorial.
#
# ## Benefícios desta abordagem
# 1. Relevância Melhorada: Expandindo consultas em documentos completos, o HyDE pode potencialmente capturar mais matizes matized e relevantes.
# 2. Complexo de manipulação Consultas: Particularmente útil para consultas complexas ou multifacetadas que podem ser difíceis de combinar diretamente.
# 3. Adaptabilidade: A geração de documentos hipotéticos pode se adaptar a diferentes tipos de consultas e domínios de documentos.
# 4. Potencial para uma melhor compreensão do contexto: A consulta ampliada pode capturar melhor o contexto e a intenção por trás da pergunta original.
#
# ## Detalhes da implementação
# 1. Utiliza o modelo ChatGPT do OpenAI para geração de documentos hipotéticos.
# 2. Emprega FAISS para uma busca de similaridade eficiente no espaço vetorial.
# 3. Permite uma visualização fácil tanto do documento hipotético quanto dos resultados recuperados.
#
# ## Conclusão
# O Embedding de Documentos Hipotéticos (HyDE) representa uma abordagem inovadora para recuperação de documentos, abordando a lacuna semântica entre consultas e documentos. Ao alavancar modelos avançados de linguagem para expandir consultas em documentos hipotéticos, HyDE tem o potencial de melhorar significativamente a relevância da recuperação, especialmente para consultas complexas ou nuances. Essa técnica poderia ser particularmente valiosa em domínios onde compreender a intenção e o contexto da consulta é crucial, como pesquisa jurídica, revisão de literatura acadêmica ou sistemas avançados de recuperação de informações.

# %% [markdown]
# <div style="text-align: center;">
#
# <img src="../images/HyDe.svg" alt="HyDe" style="width:40%; height:auto;">
# </div>

# %% [markdown]
# <div style="text-align: center;">
#
# <img src="../images/hyde-advantages.svg" alt="HyDe" style="width:100%; height:auto;">
# </div>

# %% [markdown]
# # Instalação e Importações do Pacote
# A célula abaixo instala todos os pacotes necessários para executar este notebook.
# .

# %%
# Install required packages
# !pip install python-dotenv

# %%
# Clone the repository to access helper functions and evaluation modules
# !git clone https://github.com/NirDiamant/RAG_TECHNIQUES.git
import sys
sys.path.append('RAG_TECHNIQUES')
# If you need to run with the latest data
# !cp -r RAG_TECHNIQUES/data .

# %%
import os
import sys
from dotenv import load_dotenv


# Original path append replaced for Colab compatibility
from helper_functions import *
from evaluation.evalute_rag import *

# Load environment variables from a .env file
load_dotenv()

# Set the OpenAI API key environment variable
os.environ["OPENAI_API_KEY"] = os.getenv('OPENAI_API_KEY')

# %% [markdown]
# ## Definir o caminho do documento

# %%
# Download required data files
import os
os.makedirs('data', exist_ok=True)

# Download the PDF document used in this notebook
# !wget -O data/Understanding_Climate_Change.pdf https://raw.githubusercontent.com/NirDiamant/RAG_TECHNIQUES/main/data/Understanding_Climate_Change.pdf
# !wget -O data/Understanding_Climate_Change.pdf https://raw.githubusercontent.com/NirDiamant/RAG_TECHNIQUES/main/data/Understanding_Climate_Change.pdf

# %%
path = "data/Understanding_Climate_Change.pdf"

# %% [markdown]
# ### Defina a classe HyDe retriever - criando vector store, gerando documento hipotético e recuperando

# %%
class HyDERetriever:
    def __init__(self, files_path, chunk_size=500, chunk_overlap=100):
        self.llm = ChatOpenAI(temperature=0, model_name="gpt-4o-mini", max_tokens=4000)

        self.embeddings = OpenAIEmbeddings()
        self.chunk_size = chunk_size
        self.chunk_overlap = chunk_overlap
        self.vectorstore = encode_pdf(files_path, chunk_size=self.chunk_size, chunk_overlap=self.chunk_overlap)
    
        
        self.hyde_prompt = PromptTemplate(
            input_variables=["query", "chunk_size"],
            template="""Given the question '{query}', generate a hypothetical document that directly answers this question. The document should be detailed and in-depth.
            the document size has be exactly {chunk_size} characters.""",
        )
        self.hyde_chain = self.hyde_prompt | self.llm

    def generate_hypothetical_document(self, query):
        input_variables = {"query": query, "chunk_size": self.chunk_size}
        return self.hyde_chain.invoke(input_variables).content

    def retrieve(self, query, k=3):
        hypothetical_doc = self.generate_hypothetical_document(query)
        similar_docs = self.vectorstore.similarity_search(hypothetical_doc, k=k)
        return similar_docs, hypothetical_doc

# %% [markdown]
# ## Criar uma instância de recuperação HyDe

# %%
retriever = HyDERetriever(path)

# %% [markdown]
# ## Demonstrar num caso de uso

# %%
test_query = "What is the main cause of climate change?"
results, hypothetical_doc = retriever.retrieve(test_query)

# %% [markdown]
# ### Trace o documento hipotético e as documnets recuperadas

# %%
docs_content = [doc.page_content for doc in results]

print("hypothetical_doc:\n")
print(text_wrap(hypothetical_doc)+"\n")
show_context(docs_content)

# %% [markdown]
# ![](https://europe-west1-rag-techniques-views-tracker.cloudfunctions.net/rag-techniques-tracker?notebook=all-rag-techniques--hyde-hypothetical-document-embedding)
