# %% [markdown]
# # Embutimentos de Prompt Hipotéticos (HyPE)
# ## Visão Geral
# Este código implementa um sistema Retrieval-Augmented Generation (RAG) melhorado por Embutimentos de Prompt Hipotéticos (HyPE). Ao contrário de pipelines tradicionais RAG que lutam com incompatibilidade estilo consulta-document, HyPE pré-computa perguntas hipotéticas durante a fase de indexação. Isso transforma a recuperação em um problema de correspondência de perguntas, eliminando a necessidade de técnicas de expansão de consultas em tempo de execução caras.
#
# ## Componentes-chave do caderno
#
# 1. Processamento e extração de texto PDF
# 2. Bloco de texto para manter unidades de informação coerentes
# 3. ** Geração Hypothetical Prompt Embedding** usando um LLM para criar várias perguntas proxy por bloco
# 4. Criação de armazenamento de vetor usando as incorporações [FAISS](https://engineering.fb.com/2017/03/29/data-infrastructure/faiss-a-library-for-efficient-similarity-search/) e OpenAI
# 5. Configuração do retriever para consultar os documentos processados
# 6. Avaliação do sistema RAG
#
# ## Detalhes do método
# Pré-processamento de documentos
#
# 1. O PDF é carregado usando `PyPDFLoader`.
# 2. O texto é dividido em chunks usando `RecursiveCharacterTextSplitter` com tamanho e sobreposição de chunks especificados.
#
# Geração de perguntas hipotéticas
#
# Em vez de incorporar chunks de texto brutos, HyPE ** gera múltiplos prompts hipotéticos** para cada bloco. Estas ** perguntas pré-computadas** simulam consultas de usuários, melhorando o alinhamento com pesquisas do mundo real. Isso remove a necessidade de geração de resposta sintética em tempo de execução necessária em técnicas como HyDE.
#
# Criação da Loja Vector
#
# 1. Cada pergunta hipotética é incorporada usando embeddings da OpenAI.
# 2. Uma vector store FAISS é construída, associando **cada questão incorporada ao seu bloco original**.
# 3. Esta abordagem ** armazena múltiplas representações por chunk**, aumentando a flexibilidade de recuperação.
#
# Configuração do retriever
#
# 1. O retriever é otimizado para ** question matching** ao invés de recuperação direta de documentos.
# 2. O índice FAISS permite ** eficiente vizinhança mais próxima** pesquisa sobre as incorporações hipotéticas de prompt.
# 3. Os chunks recuperados fornecem um contexto ** mais rico e preciso** para geração LLM a jusante.
#
# ## Características Principais
#
# 1. **Prompts hipotéticos pré-computados** – Melhora o alinhamento da consulta sem sobrecarga de execução.
# 2. ** Representação Multi-Vector**– Cada bloco é indexado várias vezes para uma cobertura semântica mais ampla.
# 3. ** Efficient Retrieval** – FAISS garante rápida busca de similaridade sobre as incorporações melhoradas.
# 4. **Modular Design** – O pipeline é fácil de adaptar para diferentes conjuntos de dados e configurações de recuperação. Além disso, é compatível com a maioria das otimizações, como reranking etc.
#
# ## Avaliação
# A eficácia do HyPE é avaliada em vários conjuntos de dados, mostrando:
#
# - Melhoria de até 42 pontos percentuais na precisão de recuperação
# - Até 45 pontos percentuais de melhoria no pedido de reembolso
# (Ver resultados de avaliação completos em [preprint](https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5139335))
#
# ## Benefícios desta abordagem
# 1. ** Elimina Consulta-Tempo Overhead** – Toda a geração hipotética é feita offline na indexação.
# 2. ** Melhor alinhamento entre consultas e conteúdo armazenado.
# 3. ** Escalável & Eficiente** Nenhum custo computacional por consulta; recuperação é tão rápida quanto o padrão RAG.
# 4. **Flexible & Extensible** – Pode ser combinado com técnicas avançadas RAG como reranking.
#
# ## Conclusão
# O HyPE oferece uma alternativa escalável e eficiente para sistemas RAG tradicionais, superando o descompasso do estilo consulta-documento, evitando o custo computacional da expansão de consultas em tempo de execução. Ao mover a hipotética geração rápida para indexação, ela melhora significativamente a precisão e eficiência de recuperação, tornando-a uma solução prática para aplicações do mundo real.
#
# Para mais detalhes, consulte o artigo completo: [preprint](https://papers.ssrn.com/sol3/papers.cfm?abstract_id=5139335)
#
#
# <div style="text-align: center;">
#
# <img src="../images/hype.svg" alt="HyPE" style="width:70%; height:auto;">
# </div>

# %% [markdown]
# # Instalação e Importações do Pacote
# A célula abaixo instala todos os pacotes necessários para executar este notebook.

# %%
# Install required packages
# !pip install faiss-cpu futures langchain-community python-dotenv tqdm

# %%
# Clone the repository to access helper functions and evaluation modules
# !git clone https://github.com/NirDiamant/RAG_TECHNIQUES.git
import sys
sys.path.append('RAG_TECHNIQUES')
# If you need to run with the latest data
# !cp -r RAG_TECHNIQUES/data .

# %%
import os
import sys
import faiss
from tqdm import tqdm
from dotenv import load_dotenv
from concurrent.futures import ThreadPoolExecutor, as_completed
from langchain_community.docstore.in_memory import InMemoryDocstore


# Load environment variables from a .env file
load_dotenv()

# Set the OpenAI API key environment variable (comment out if not using OpenAI)
if not os.getenv('OPENAI_API_KEY'):
    os.environ["OPENAI_API_KEY"] = input("Please enter your OpenAI API key: ")
else:
    os.environ["OPENAI_API_KEY"] = os.getenv('OPENAI_API_KEY')

# Original path append replaced for Colab compatibility
from helper_functions import *
from evaluation.evalute_rag import *

# %% [markdown]
# Define constantes
#
# - `PATH`: caminho para os dados, para ser incorporado no pipeline RAG
#
# Este tutorial usa o endpoint OpenAI ([modelos avalible](https://platform.openai.com/docs/pricing)).
# - `LANGUAGE_MODEL_NAME`: O nome do modelo de linguagem a ser utilizado.
# - `EMBEDDING_MODEL_NAME`: O nome do modelo de incorporação a ser usado.
#
# O tutroial usa uma abordagem de chunks `RecursiveCharacterTextSplitter` onde a função de comprimento de chunks usada é a função python `len`. As varáveis para serem ajustadas aqui são:
# - `CHUNK_SIZE`: O comprimento mínimo de um chunk
# - `CHUNK_OVERLAP`: A sobreposição de dois chunks consecutivos.

# %%
# Download required data files
import os
os.makedirs('data', exist_ok=True)

# Download the PDF document used in this notebook
# !wget -O data/Understanding_Climate_Change.pdf https://raw.githubusercontent.com/NirDiamant/RAG_TECHNIQUES/main/data/Understanding_Climate_Change.pdf
# !wget -O data/Understanding_Climate_Change.pdf https://raw.githubusercontent.com/NirDiamant/RAG_TECHNIQUES/main/data/Understanding_Climate_Change.pdf

# %%
PATH = "data/Understanding_Climate_Change.pdf"
LANGUAGE_MODEL_NAME = "gpt-4o-mini"
EMBEDDING_MODEL_NAME = "text-embedding-3-small"
CHUNK_SIZE = 1000
CHUNK_OVERLAP = 200

# %% [markdown]
# ## Define geração de Embutimentos Hipotéticos
#
# O bloco de código abaixo gera perguntas hipotéticas para cada bloco de texto e as incorpora para recuperação.
#
# - Um LLM extrai perguntas-chave do bloco de entrada.
# - Não. Essas perguntas são incorporadas usando o modelo do OpenAI.
# - Não. A função retorna o bloco original e suas incorporações imediatas mais tarde usadas para recuperação.
#
# Para garantir uma saída limpa, novas linhas extras são removidas, e a análise regex pode melhorar a formatação da lista quando necessário.

# %%
def generate_hypothetical_prompt_embeddings(chunk_text: str):
    """
    Uses the LLM to generate multiple hypothetical questions for a single chunk.
    These questions will be used as 'proxies' for the chunk during retrieval.

    Parameters:
    chunk_text (str): Text contents of the chunk

    Returns:
    chunk_text (str): Text contents of the chunk. This is done to make the 
        multithreading easier
    hypothetical prompt embeddings (List[float]): A list of embedding vectors
        generated from the questions
    """
    llm = ChatOpenAI(temperature=0, model_name=LANGUAGE_MODEL_NAME)
    embedding_model = OpenAIEmbeddings(model=EMBEDDING_MODEL_NAME)

    question_gen_prompt = PromptTemplate.from_template(
        "Analyze the input text and generate essential questions that, when answered, \
        capture the main points of the text. Each question should be one line, \
        without numbering or prefixes.\n\n \
        Text:\n{chunk_text}\n\nQuestions:\n"
    )
    question_chain = question_gen_prompt | llm | StrOutputParser()

    # parse questions from response
    # Notes: 
    # - gpt4o likes to split questions by \n\n so we remove one \n
    # - for production or if using smaller models from ollama, it's beneficial to use regex to parse 
    # things like (un)ordeed lists
    # r"^\s*[\-\*\•]|\s*\d+\.\s*|\s*[a-zA-Z]\)\s*|\s*\(\d+\)\s*|\s*\([a-zA-Z]\)\s*|\s*\([ivxlcdm]+\)\s*"
    questions = question_chain.invoke({"chunk_text": chunk_text}).replace("\n\n", "\n").split("\n")
    
    return chunk_text, embedding_model.embed_documents(questions)

# %% [markdown]
# ### Defina a criação e população da Loja de Vetores FAISS
#
# O bloco de código abaixo constrói uma vector store FAISS incorporando chunks de texto em paralelo.
#
# O que acontece?
# - Processamento paralelo – Usa threading para gerar incorporações mais rápido.
# - Inicialização FAISS – Define um índice L2 para uma pesquisa eficiente de similaridade.
# - Embutimento Chunk – Cada bloco é armazenado várias vezes, uma vez para cada incorporação de questões gerada.
# - Armazenamento na memória – Usa o InMemoryDocstore para uma rápida pesquisa.
#
# Isso garante uma recuperação eficiente, melhorando o alinhamento de consultas com incorporações de perguntas pré-computadas.

# %%
def prepare_vector_store(chunks: List[str]):
    """
    Creates and populates a FAISS vector store from a list of text chunks.

    This function processes a list of text chunks in parallel, generating 
    hypothetical prompt embeddings for each chunk.
    The embeddings are stored in a FAISS index for efficient similarity search.

    Parameters:
    chunks (List[str]): A list of text chunks to be embedded and stored.

    Returns:
    FAISS: A FAISS vector store containing the embedded text chunks.
    """

    # Wait with initialization to see vector lengths
    vector_store = None  

    with ThreadPoolExecutor() as pool:  
        # Use threading to speed up generation of prompt embeddings
        futures = [pool.submit(generate_hypothetical_prompt_embeddings, c) for c in chunks]
        
        # Process embeddings as they complete
        for f in tqdm(as_completed(futures), total=len(chunks)):  
            
            chunk, vectors = f.result()  # Retrieve the processed chunk and its embeddings
            
            # Initialize the FAISS vector store on the first chunk
            if vector_store == None:  
                vector_store = FAISS(
                    embedding_function=OpenAIEmbeddings(model=EMBEDDING_MODEL_NAME),  # Define embedding model
                    index=faiss.IndexFlatL2(len(vectors[0]))  # Define an L2 index for similarity search
                    docstore=InMemoryDocstore(),  # Use in-memory document storage
                    index_to_docstore_id={}  # Maintain index-to-document mapping
                )
            
            # Pair the chunk's content with each generated embedding vector.
            # Each chunk is inserted multiple times, once for each prompt vector
            chunks_with_embedding_vectors = [(chunk.page_content, vec) for vec in vectors]
            
            # Add embeddings to the store
            vector_store.add_embeddings(chunks_with_embedding_vectors)  

    return vector_store  # Return the populated vector store

# %% [markdown]
# ### Codifique PDF em uma Loja de Vetores FAISS
#
# O bloco de código abaixo processa um arquivo PDF e armazena seu conteúdo como incorporações para recuperação.
#
# O que acontece?
# - Carregamento PDF – Extrai texto do documento.
# - Chunking – Dividi texto em segmentos sobrepostos para melhor retenção de contexto.
# - Pré-processamento – Limpa o texto para melhorar a qualidade de incorporação.
# - Criação de loja Vector – Gera incorporações e armazena-as em FAISS para recuperação.

# %%
def encode_pdf(path, chunk_size=1000, chunk_overlap=200):
    """
    Encodes a PDF book into a vector store using OpenAI embeddings.

    Args:
        path: The path to the PDF file.
        chunk_size: The desired size of each text chunk.
        chunk_overlap: The amount of overlap between consecutive chunks.

    Returns:
        A FAISS vector store containing the encoded book content.
    """

    # Load PDF documents
    loader = PyPDFLoader(path)
    documents = loader.load()

    # Split documents into chunks
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size, chunk_overlap=chunk_overlap, length_function=len
    )
    texts = text_splitter.split_documents(documents)
    cleaned_texts = replace_t_with_space(texts)

    vectorstore = prepare_vector_store(cleaned_texts)

    return vectorstore

# %% [markdown]
# ## Criar HyPE armazenamento de vetores
#
# Agora processamos o PDF e armazenamos suas incorporações.
# Esta etapa inicializa o armazenamento do vetor FAISS com o documento codificado.

# %%
# Chunk size can be quite large with HyPE as we are not loosing percision with more
# information. For production, test how exhaustive your model is in generating sufficient 
# amount of questions per chunk. This will mostly depend on your information density.
chunks_vector_store = encode_pdf(PATH, chunk_size=CHUNK_SIZE, chunk_overlap=CHUNK_OVERLAP)
# Out:
# 100%|██████████| 97/97 [00:22<00:00,  4.40it/s]

# %% [markdown]
# ## Criar o Retriever
#
# Agora configuramos o retriever para obter chunks relevantes da vector store.
#
# Recupera os chunks `k=3` mais relevantes com base na similaridade da consulta.

# %%
chunks_query_retriever = chunks_vector_store.as_retriever(search_kwargs={"k": 3})

# %% [markdown]
# ### Recuperador de teste
# Agora testamos a recuperação usando uma consulta de exemplo.
#
# - Consulta a vector store para encontrar os chunks mais relevantes.
# - Desduplica os resultados para remover chunks potencialmente repetidos.
# - Mostra o contexto recuperado para inspeção.
#
# Esta etapa verifica que o retriever retorna informações significativas e diversas para a pergunta dada.

# %%
test_query = "What is the main cause of climate change?"
context = retrieve_context_per_question(test_query, chunks_query_retriever)
context = list(set(context))
show_context(context)
# Out:
# Context 1:
# Most of these climate changes are attributed to very small variations in Earth's orbit that
# change the amount of solar energy our planet receives. During the Holocene epoch, which
# began at the end of the last ice age, human societies f lourished, but the industrial era has seen
# unprecedented changes.
# Modern Observations
# Modern scientific observations indicate a rapid increase in global temperatures, sea levels,
# and extreme weather events. The Intergovernmental Panel on Climate Change (IPCC) has
# documented these changes extensively. Ice core samples, tree rings, and ocean sediments
# provide a historical record that scientists use to understand past climate conditions and
# predict future trends. The evidence overwhelmingly shows that recent changes are primarily
# driven by human activities, particularly the emission of greenhou se gases.
# Chapter 2: Causes of Climate Change
# Greenhouse Gases
#
#
# Context 2:
# ...

# %% [markdown]
# ### Avaliar os resultados

# %%
evaluate_rag(chunks_query_retriever)
# Out:
# {'questions': ['1. **Multiple Choice: Causes of Climate Change**',
#   '   - What is the primary cause of the current climate change trend?',
#   '     A) Solar radiation variations',
#   '     B) Natural cycles of the Earth',
#   '     C) Human activities, such as burning fossil fuels',
#   '     D) Volcanic eruptions',
#   '',
#   '2. **True or False: Impact on Biodiversity**',
#   '   - True or False: Climate change does not have any significant impact on the migration patterns and extinction rates of various species.',
#   '',
#   '3. **Short Answer: Mitigation Strategies**',
#   '   - What are two effective strategies that can be implemented at a community level to mitigate the effects of climate change?',
#   '',
#   '4. **Matching: Climate Change Effects**',
#   '   - Match the following effects of climate change (numbered) with their likely consequences (lettered).',
#   '     1. Rising sea levels',
#   '     2. Increased frequency of extreme weather events',
# ...

# %% [markdown]
# ![](https://europe-west1-rag-techniques-views-tracker.cloudfunctions.net/rag-techniques-tracker?notebook=all-rag-techniques--hype-hypothetical-prompt-embeddings)
