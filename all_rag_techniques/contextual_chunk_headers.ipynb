# %% [markdown]
# # Cabeçalhos de Chunk contextual (CCH)
# ## Visão Geral
# Cabeçalhos de chunks contextuais (CCH) é um método de criação de cabeçalhos de chunks que contêm contexto de nível superior (como nível de documento ou nível de seção), e pré-pendendo esses cabeçalhos de chunks para os chunks antes de incorporá-los. Isso dá às incorporações uma representação muito mais precisa e completa do conteúdo e significado do texto. Em nossos testes, esta característica leva a uma melhoria substancial na qualidade de recuperação. Além de aumentar a taxa em que as informações corretas são recuperadas, a CCH também reduz a taxa em que os resultados irrelevantes aparecem nos resultados da pesquisa. Isso reduz a taxa em que o LLM interpreta mal um chunk de texto em aplicativos de chat e geração a jusante.
#
# ## Motivação
# Muitos dos problemas que os desenvolvedores enfrentam com RAG se resumem a isso: Os chunks individuais muitas vezes não contêm contexto suficiente para ser usado corretamente pelo sistema de recuperação ou pelo LLM. Isso leva à incapacidade de responder perguntas e, mais preocupantemente, alucinações.
#
# Exemplos deste problema
# - Chunks muitas vezes se referem ao seu assunto através de referências implícitas e pronomes. Isso faz com que não sejam recuperados quando deveriam ser, ou não sejam devidamente compreendidos pela LLM.
# - Os chunks individuais muitas vezes só fazem sentido no contexto de toda a seção ou documento, e pode ser enganador quando lido por conta própria.
#
# ## Componentes-chave
#
# Cabeçalhos de chunks contextuais
# A ideia aqui é adicionar no contexto de nível superior ao bloco, antecipando um cabeçalho de bloco. Este cabeçalho de bloco pode ser tão simples quanto o título do documento, ou pode usar uma combinação de título do documento, um resumo conciso do documento, e a hierarquia completa de títulos de seção e sub-seção.
#
# ## Detalhes do método
# #### Geração de contextoNa demonstração abaixo usamos um LLM para gerar um título descritivo para o documento. Isso é feito através de um simples prompt onde você passa em uma versão truncada do texto do documento e pede ao LLM para gerar um título descritivo para o documento. Se você já tiver títulos de documentos suficientemente descritivos, então você pode usá-los diretamente. Descobrimos que um título de documento é o tipo mais simples e mais importante de contexto de alto nível para incluir no cabeçalho do bloco.
#
# Outros tipos de contexto que você pode incluir no cabeçalho do bloco:
# - Resumo do documento conciso
# - Título(s) da secção/subsecção
# - Não. Isso ajuda o sistema de recuperação a lidar com consultas para seções maiores ou tópicos em documentos.
#
# #### Incorpore chunks com cabeçalhos de chunksO texto que você incorpora para cada bloco é simplesmente a concatenação do cabeçalho do bloco e do texto do bloco. Se você usar um reranker durante a recuperação, você vai querer ter certeza de que você usa esta mesma concatenação lá também.
#
# #### Adicionar cabeçalhos de chunks aos resultados da pesquisaIncluir os cabeçalhos de chunks ao apresentar os resultados de pesquisa para o LLM também é benéfico, pois dá ao LLM mais contexto, e torna menos provável que ele entenda mal o significado de um bloco.

# %% [markdown]
# ! [Seu nome de técnica](../imagens/contextual_chunk_headers.svg)

# %% [markdown]
# Configuração
#
# Você precisará de uma chave API e uma chave OpenAI API para este notebook.

# %% [markdown]
# # Instalação e Importações do Pacote
# A célula abaixo instala todos os pacotes necessários para executar este notebook.
# .

# %%
# Install required packages
# !pip install langchain openai python-dotenv tiktoken

# %%
import cohere
import tiktoken
from typing import List
from openai import OpenAI
import os
from dotenv import load_dotenv
from langchain_text_splitters import RecursiveCharacterTextSplitter

# Load environment variables from a .env file
load_dotenv()
os.environ["CO_API_KEY"] = os.getenv('CO_API_KEY') # Cohere API key
os.environ["OPENAI_API_KEY"] = os.getenv('OPENAI_API_KEY') # OpenAI API key

# %% [markdown]
# ## Carregar o documento e dividi- lo em chunks
# Vamos usar o LangChain RecursiveCharacterTextSplitter básico para esta demonstração, mas você pode combinar CCH com métodos de chunks mais sofisticados para um desempenho ainda melhor.

# %%
# Download required data files
import os
os.makedirs('data', exist_ok=True)

# Download the PDF document used in this notebook
# !wget -O data/Understanding_Climate_Change.pdf https://raw.githubusercontent.com/NirDiamant/RAG_TECHNIQUES/main/data/Understanding_Climate_Change.pdf
# !wget -O data/nike_2023_annual_report.txt https://raw.githubusercontent.com/NirDiamant/RAG_TECHNIQUES/main/data/nike_2023_annual_report.txt

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

def split_into_chunks(text: str, chunk_size: int = 800) -> list[str]:
    """
    Split a given text into chunks of specified size using RecursiveCharacterTextSplitter.

    Args:
        text (str): The input text to be split into chunks.
        chunk_size (int, optional): The maximum size of each chunk. Defaults to 800.

    Returns:
        list[str]: A list of text chunks.

    Example:
        >>> text = "This is a sample text to be split into chunks."
        >>> chunks = split_into_chunks(text, chunk_size=10)
        >>> print(chunks)
        ['This is a', 'sample', 'text to', 'be split', 'into', 'chunks.']
    """
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size,
        chunk_overlap=0,
        length_function=len
    )
    documents = text_splitter.create_documents([text])
    return [document.page_content for document in documents]

# File path for the input document
FILE_PATH = "data/nike_2023_annual_report.txt"

# Read the document and split it into chunks
with open(FILE_PATH, "r") as file:
    document_text = file.read()

chunks = split_into_chunks(document_text, chunk_size=800)

# %% [markdown]
# ## Gerar título do documento descritivo para usar no cabeçalho do bloco

# %%
# Constants
DOCUMENT_TITLE_PROMPT = """
INSTRUCTIONS
What is the title of the following document?

Your response MUST be the title of the document, and nothing else. DO NOT respond with anything else.

{document_title_guidance}

{truncation_message}

DOCUMENT
{document_text}
""".strip()

TRUNCATION_MESSAGE = """
Also note that the document text provided below is just the first ~{num_words} words of the document. That should be plenty for this task. Your response should still pertain to the entire document, not just the text provided below.
""".strip()

MAX_CONTENT_TOKENS = 4000
MODEL_NAME = "gpt-4o-mini"
TOKEN_ENCODER = tiktoken.encoding_for_model('gpt-3.5-turbo')

def make_llm_call(chat_messages: list[dict]) -> str:
    """
    Make an API call to the OpenAI language model.

    Args:
        chat_messages (list[dict]): A list of message dictionaries for the chat completion.

    Returns:
        str: The generated response from the language model.
    """
    client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
    response = client.chat.completions.create(
        model=MODEL_NAME,
        messages=chat_messages,
        max_tokens=MAX_CONTENT_TOKENS,
        temperature=0.2,
    )
    return response.choices[0].message.content.strip()

def truncate_content(content: str, max_tokens: int) -> tuple[str, int]:
    """
    Truncate the content to a specified maximum number of tokens.

    Args:
        content (str): The input text to be truncated.
        max_tokens (int): The maximum number of tokens to keep.

    Returns:
        tuple[str, int]: A tuple containing the truncated content and the number of tokens.
    """
    tokens = TOKEN_ENCODER.encode(content, disallowed_special=())
    truncated_tokens = tokens[:max_tokens]
    return TOKEN_ENCODER.decode(truncated_tokens), min(len(tokens), max_tokens)

def get_document_title(document_text: str, document_title_guidance: str = "") -> str:
    """
    Extract the title of a document using a language model.

    Args:
        document_text (str): The text of the document.
        document_title_guidance (str, optional): Additional guidance for title extraction. Defaults to "".

    Returns:
        str: The extracted document title.
    """
    # Truncate the content if it's too long
    document_text, num_tokens = truncate_content(document_text, MAX_CONTENT_TOKENS)
    truncation_message = TRUNCATION_MESSAGE.format(num_words=3000) if num_tokens >= MAX_CONTENT_TOKENS else ""

    # Prepare the prompt for title extraction
    prompt = DOCUMENT_TITLE_PROMPT.format(
        document_title_guidance=document_title_guidance,
        document_text=document_text,
        truncation_message=truncation_message
    )
    chat_messages = [{"role": "user", "content": prompt}]
    
    return make_llm_call(chat_messages)

# Example usage
if __name__ == "__main__":
    # Assuming document_text is defined elsewhere
    document_title = get_document_title(document_text)
    print(f"Document Title: {document_title}")
# Out:
# NIKE, INC. ANNUAL REPORT ON FORM 10-K

# %% [markdown]
# ## Adicionar o cabeçalho do bloco e medir o impacto
# Vamos olhar para um exemplo específico para demonstrar o impacto de adicionar um cabeçalho de bloco. Vamos usar o reranker Cohere para medir a relevância de uma consulta com e sem um cabeçalho de bloco.

# %%
def rerank_documents(query: str, chunks: List[str]) -> List[float]:
    """
    Use Cohere Rerank API to rerank the search results.

    Args:
        query (str): The search query.
        chunks (List[str]): List of document chunks to be reranked.

    Returns:
        List[float]: List of similarity scores for each chunk, in the original order.
    """
    MODEL = "rerank-english-v3.0"
    client = cohere.Client(api_key=os.environ["CO_API_KEY"])

    reranked_results = client.rerank(model=MODEL, query=query, documents=chunks)
    results = reranked_results.results
    reranked_indices = [result.index for result in results]
    reranked_similarity_scores = [result.relevance_score for result in results]
    
    # Convert back to order of original documents
    similarity_scores = [0] * len(chunks)
    for i, index in enumerate(reranked_indices):
        similarity_scores[index] = reranked_similarity_scores[i]

    return similarity_scores

def compare_chunk_similarities(chunk_index: int, chunks: List[str], document_title: str, query: str) -> None:
    """
    Compare similarity scores for a chunk with and without a contextual header.

    Args:
        chunk_index (int): Index of the chunk to inspect.
        chunks (List[str]): List of all document chunks.
        document_title (str): Title of the document.
        query (str): The search query to use for comparison.

    Prints:
        Chunk header, chunk text, query, and similarity scores with and without the header.
    """
    chunk_text = chunks[chunk_index]
    chunk_wo_header = chunk_text
    chunk_w_header = f"Document Title: {document_title}\n\n{chunk_text}"

    similarity_scores = rerank_documents(query, [chunk_wo_header, chunk_w_header])

    print(f"\nChunk header:\nDocument Title: {document_title}")
    print(f"\nChunk text:\n{chunk_text}")
    print(f"\nQuery: {query}")
    print(f"\nSimilarity without contextual chunk header: {similarity_scores[0]:.4f}")
    print(f"Similarity with contextual chunk header: {similarity_scores[1]:.4f}")

# Notebook cell for execution
# Assuming chunks and document_title are defined in previous cells
CHUNK_INDEX_TO_INSPECT = 86
QUERY = "Nike climate change impact"

compare_chunk_similarities(CHUNK_INDEX_TO_INSPECT, chunks, document_title, QUERY)
# Out:
# Chunk header:
# Document Title: NIKE, INC. ANNUAL REPORT ON FORM 10-K
#
# Chunk text:
# Given the broad and global scope of our operations, we are particularly vulnerable to the physical risks of climate change, such
# as shifts in weather patterns. Extreme weather conditions in the areas in which our retail stores, suppliers, manufacturers,
# customers, distribution centers, offices, headquarters and vendors are located could adversely affect our operating results and
# financial condition. Moreover, natural disasters such as earthquakes, hurricanes, wildfires, tsunamis, floods or droughts, whether
# occurring in the United States or abroad, and their related consequences and effects, including energy shortages and public
# health issues, have in the past temporarily disrupted, and could in the future disrupt, our operations, the operations of our
#
# Query: Nike climate change impact
#
# Similarity w/o contextual chunk header: 0.10576342
# ...

# %% [markdown]
# Esta parte é claramente sobre o impacto da mudança climática em alguma organização, mas não diz explicitamente "Nike" nela. Assim, a relevância para a consulta "Impacto da mudança climática Nike" em apenas cerca de 0,1. Ao simplesmente adicionar o título do documento ao bloco que a similaridade vai até 0,92.

# %% [markdown]
# ## Resultados da avaliação
# KITE
#
# Avaliamos o CCH em um benchmark RAG de ponta a ponta que criamos, chamado KITE (Knowledge-Intensive Task Evaluation).
#
# O KITE consiste actualmente em 4 conjuntos de dados e num total de 50 questões.
# - **AI Papers** - ~100 trabalhos acadêmicos sobre IA e RAG, baixados do arXiv no formulário PDF.
# - **BVP Cloud 10Ks** - 10Ks para todas as empresas do Índice de Nuvem de Bessemer (~70 delas), na forma PDF.
# - **Sourcegraph Company Handbook** - ~800 arquivos de marcação, com sua estrutura de diretório original, baixados do manual de empresa acessível ao público GitHub [page](https://github.com/sourcegraph/handbook/tree/main/content).
# - **Opinião do Supremo Tribunal** - Todos os pareceres do Supremo Tribunal do ano 2022 (entrega de janeiro de 23 e junho de 23), baixados do Supremo Tribunal oficial [website](https://www.supremecourt.gov/opinions/slipopinion/22) no formulário PDF.
#
# As respostas de verdade são incluídas em cada amostra. A maioria das amostras também incluem rubrics de classificação. A graduação é feita em uma escala de 0-10 para cada questão, com um LLM forte fazendo a classificação.
#
# Comparamos o desempenho com e sem CCH. Para a configuração do CCH usamos o título do documento e o resumo do documento. Todos os outros parâmetros permanecem os mesmos entre as duas configurações. Usamos o reranker Cohere 3, e usamos GPT-4o para geração de resposta.
#
# No-CCH
# --------------------------------
# AI Papers 4.5 4.7
# Nuvem do BVP 2.6 6.3
# Fonte:
# Opinião do Supremo Tribunal
# * Média** * 4.72
#
# Podemos ver que o CCH leva a uma melhoria no desempenho em cada um dos quatro conjuntos de dados. Alguns conjuntos de dados vêem uma grande melhoria, enquanto outros vêem uma pequena melhoria. O escore médio global aumenta de 4,72 -> 6,04, um aumento de 27,9%.
#
# FinanceBench
#
# Também avaliamos a CCH no FinanceBench, onde contribuiu para um escore de 83%, em comparação com um escore basal de 19%. Para esse benchmark, testamos CCH e extração de segmento relevante (RSE) em conjunto, então não podemos dizer exatamente quanto CCH contribuiu para esse resultado. Mas a combinação de CCH e RSE claramente leva a melhorias substanciais de precisão no FinanceBench.

# %% [markdown]
# ![](https://europe-west1-rag-techniques-views-tracker.cloudfunctions.net/rag-techniques-tracker?notebook=all-rag-techniques--contextual-chunk-headers)
