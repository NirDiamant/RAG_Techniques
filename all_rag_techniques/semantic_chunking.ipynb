# %% [markdown]
# # Chunking Semântico para Processamento de Documentos
# ## Visão Geral
# Este código implementa uma abordagem de chunks semânticos para processamento e recuperação de informações de documentos PDF, [primeiro proposto por Greg Kamradt](https://youtu.be/8OJC21T2SL4?t=1933) e, posteriormente [implementado em LangChain](https://python.langchain.com/docs/how_to/semantic-chunker/). Ao contrário dos métodos tradicionais que dividem texto baseado em contagens fixas de caracteres ou palavras, o blocing semântico visa criar segmentos de texto mais significativos e conscientes do contexto.
#
# ## Motivação
# Os métodos tradicionais de divisão de texto muitas vezes quebram documentos em pontos arbitrários, potencialmente interrompendo o fluxo de informação e contexto. O bloco semântico aborda esta questão tentando dividir texto em pontos de interrupção mais naturais, preservando a coerência semântica dentro de cada bloco.
#
# ## Componentes-chave
#
# 1. Processamento e extração de texto PDF
# 2. Bloqueio semântico usando LangChain SemanticChunker
# 3. Criação de armazenamento de vetor usando incorporações FAISS e OpenAI
# 4. Configuração do retriever para consultar os documentos processados
#
# ## Detalhes do método
# Pré-processamento de documentos
#
# 1. O PDF é lido e convertido para uma string usando uma função personalizada `read_pdf_to_string`.
#
# Chunking Semântico
#
# 1. Utiliza LangChain `SemanticChunker` com embeddings da OpenAI.
# 2. Estão disponíveis três tipos de pontos de paragem:
# - 'percentil': divide-se em diferenças superiores ao percentil X.
# - 'standard_deviation': Dividi em diferenças superiores a X desvios-padrão.
# - interquartil: Usa a distância interquartil para determinar pontos separados.
# 3. Nesta implementação, o método "percentil" é utilizado com um limiar de 90.
#
# Criação da Loja Vector
#
# 1. As embeddings da OpenAI são usadas para criar representações vetoriais dos chunks semânticos.
# 2. Uma vector store FAISS é criada a partir desses embeddings para uma busca de similaridade eficiente.
#
# Configuração do retriever
#
# 1. Um retriever está configurado para obter os 2 chunks mais relevantes para uma determinada consulta.
#
# ## Características Principais
#
# 1. Dividindo Contexto- Aware: Tenta manter a coerência semântica dentro de chunks.
# 2. Configuração flexível: Permite diferentes tipos de pontos de paragem e limiares.
# 3. Integração com NLP avançado Ferramentas: Usa embeddings da OpenAI tanto para chunks quanto para recuperação.
#
# ## Benefícios desta abordagem
# 1. Melhor coerência: Chunks são mais propensos a conter pensamentos completos ou idéias.
# 2. Melhor Relevância de Recuperação: Ao preservar o contexto, a precisão de recuperação pode ser melhorada.
# 3. Adaptabilidade: O método de chunks pode ser ajustado com base na natureza dos documentos e necessidades de recuperação.
# 4. Potencial para uma melhor compreensão: LLMs ou tarefas a jusante podem funcionar melhor com segmentos de texto mais coerentes.
#
# ## Detalhes da implementação
# 1. Utiliza incorporações do OpenAI tanto para o processo de chunks semânticos quanto para as representações vetoriais finais.
# 2. Emprega FAISS para criar um índice pesquisável eficiente dos chunks.
# 3. O retriever é configurado para retornar os 2 chunks mais relevantes, que podem ser ajustados conforme necessário.
#
# ## Uso do Exemplo
#
# O código inclui uma consulta de teste: "Qual é a principal causa das mudanças climáticas?". Isso demonstra como o sistema de blocagem e recuperação semântica pode ser usado para encontrar informações relevantes do documento processado.
#
# ## Conclusão
# O bloco semântico representa uma abordagem avançada para o processamento de documentos para sistemas de recuperação. Ao tentar manter a coerência semântica dentro de segmentos de texto, ele tem o potencial de melhorar a qualidade das informações recuperadas e melhorar o desempenho de tarefas NLP a jusante. Essa técnica é particularmente valiosa para o processamento de documentos longos e complexos, onde a manutenção do contexto é crucial, como artigos científicos, documentos legais ou relatórios abrangentes.

# %% [markdown]
# <div style="text-align: center;">
#
# <img src="../images/semantic_chunking_comparison.svg" alt="Self RAG" style="width:100%; height:auto;">
# </div>

# %% [markdown]
# # Instalação e Importações do Pacote
# A célula abaixo instala todos os pacotes necessários para executar este notebook.
# .

# %%
# Install required packages
# !pip install langchain-experimental langchain-openai python-dotenv

# %%
# Clone the repository to access helper functions and evaluation modules
# !git clone https://github.com/NirDiamant/RAG_TECHNIQUES.git
import sys
sys.path.append('RAG_TECHNIQUES')
# If you need to run with the latest data
# !cp -r RAG_TECHNIQUES/data .

# %%
import os
import sys
from dotenv import load_dotenv

# Original path append replaced for Colab compatibility
from helper_functions import *
from evaluation.evalute_rag import *

from langchain_experimental.text_splitter import SemanticChunker
from langchain_openai.embeddings import OpenAIEmbeddings

# Load environment variables from a .env file
load_dotenv()

# Set the OpenAI API key environment variable
os.environ["OPENAI_API_KEY"] = os.getenv('OPENAI_API_KEY')

# %% [markdown]
# ### Definir o caminho do ficheiro

# %%
# Download required data files
import os
os.makedirs('data', exist_ok=True)

# Download the PDF document used in this notebook
# !wget -O data/Understanding_Climate_Change.pdf https://raw.githubusercontent.com/NirDiamant/RAG_TECHNIQUES/main/data/Understanding_Climate_Change.pdf
# !wget -O data/Understanding_Climate_Change.pdf https://raw.githubusercontent.com/NirDiamant/RAG_TECHNIQUES/main/data/Understanding_Climate_Change.pdf

# %%
path = "data/Understanding_Climate_Change.pdf"

# %% [markdown]
# ## Leia PDF para string

# %%
content = read_pdf_to_string(path)

# %% [markdown]
# Tipos de pontos de paragem:
# * 'percentil': todas as diferenças entre sentenças são calculadas, e então qualquer diferença maior do que o percentil X é dividida.
# * 'standard_deviation': qualquer diferença maior do que X desvios padrão é dividida.
# * 'interquartil': a distância interquartil é usada para dividir chunks.

# %%
text_splitter = SemanticChunker(OpenAIEmbeddings(), breakpoint_threshold_type='percentile', breakpoint_threshold_amount=90) # chose which embeddings and breakpoint type and threshold to use

# %% [markdown]
# ## Dividir texto original em chunks semânticos

# %%
docs = text_splitter.create_documents([content])

# %% [markdown]
# ### Criar armazenamento e recuperação de vetores

# %%
embeddings = OpenAIEmbeddings()
vectorstore = FAISS.from_documents(docs, embeddings)
chunks_query_retriever = vectorstore.as_retriever(search_kwargs={"k": 2})

# %% [markdown]
# ### Testar o recuperador

# %%
test_query = "What is the main cause of climate change?"
context = retrieve_context_per_question(test_query, chunks_query_retriever)
show_context(context)

# %% [markdown]
# ![](https://europe-west1-rag-techniques-views-tracker.cloudfunctions.net/rag-techniques-tracker?notebook=all-rag-techniques--semantic-chunking)
