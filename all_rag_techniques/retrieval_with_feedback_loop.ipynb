# %% [markdown]
# # RAG Sistema com Feedback Loop: Aumentando a qualidade de recuperação e resposta
# ## Visão Geral
# Este sistema implementa uma abordagem Retrieval-Augmented Generation (RAG) com um loop de feedback integrado. Visa melhorar a qualidade e relevância das respostas ao longo do tempo, incorporando feedback do usuário e ajustando dinamicamente o processo de recuperação.
#
# ## Motivação
# Os sistemas tradicionais RAG podem às vezes produzir respostas inconsistentes ou irrelevantes devido a limitações no processo de recuperação ou na base de conhecimento subjacente. Ao implementar um ciclo de feedback, podemos:
#
# 1. Melhorar continuamente a qualidade dos documentos recuperados
# 2. Melhorar a relevância das respostas geradas
# 3. Adaptar o sistema às preferências e necessidades do usuário ao longo do tempo
#
# ## Componentes-chave
#
# 1. ** Extração de conteúdo de PDF**: Extrai texto de documentos PDF
# 2. **Vectorstore**: Lojas e índices de incorporação de documentos para recuperação eficiente
# 3. **Retriever**: Fetches relevantes documentos baseados em consultas do usuário
# 4. **Language Model**: Gera respostas usando documentos recuperados
# 5. **Feedback Collection**: Recolhe feedback do usuário sobre qualidade e relevância da resposta
# 6. **Feedback Storage**: Persists user feedback for future use
# 7. **Relevance Score Adjustment**: Modifica a relevância do documento com base no feedback
# 8. **Index Fine-tuning**: Atualiza periodicamente o vetorstore usando feedback acumulado
#
# ## Detalhes do método
# ### 1. Configuração Inicial- Não. O sistema lê o conteúdo PDF e cria uma vector store
# - Um retriever é inicializado usando o vectorstore
# - Um modelo de linguagem (LLM) é configurado para geração de resposta
#
# ### 2. Processamento de Consultas- Não. Quando um usuário envia uma consulta, o retriever obtém documentos relevantes
# - O LLM gera uma resposta com base nos documentos recuperados
#
# ### 3. Coleção de Feedback- Não. O sistema coleta feedback do usuário sobre a relevância e qualidade da resposta
# - Feedback é armazenado em um arquivo JSON para persistência
#
# ### 4. Ajuste da pontuação da relevância- Para consultas subsequentes, o sistema carrega comentários anteriores
# - Não. Um LLM avalia a relevância do feedback passado para a consulta atual
# - As pontuações de relevância dos documentos são ajustadas com base nesta avaliação
#
# ### 5. Atualização do Retriever- Não. O recuperador é atualizado com as pontuações ajustadas do documento
# - Não. Isso garante que as futuras recuperações beneficiem de feedback passado
#
# ### 6. Ajuste fino do índice periódico- Não. A intervalos regulares, o sistema ajusta o índice
# - O feedback de alta qualidade é usado para criar documentos adicionais
# - Não. O vectorstore é atualizado com estes novos documentos, melhorando a qualidade geral de recuperação
#
# ## Benefícios desta abordagem
# 1. ** Melhoria contínua**: O sistema aprende com cada interação, aumentando gradualmente seu desempenho.
# 2. **Personalização**: Ao incorporar o feedback do usuário, o sistema pode se adaptar às preferências individuais ou de grupo ao longo do tempo.
# 3. **Relevância aumentada**: O ciclo de feedback ajuda a priorizar documentos mais relevantes em futuras recuperações.
# 4. ** Controle de Qualidade**: Respostas de baixa qualidade ou irrelevantes são menos prováveis de serem repetidas à medida que o sistema evolui.
# 5. ** Adaptabilidade**: O sistema pode ajustar-se às mudanças nas necessidades do usuário ou no conteúdo do documento ao longo do tempo.
#
# ## Conclusão
# Este sistema RAG com um loop de feedback representa um avanço significativo sobre implementações tradicionais RAG. Ao aprender continuamente com as interações do usuário, ele oferece uma abordagem mais dinâmica, adaptativa e centrada no usuário para recuperação de informações e geração de resposta. Este sistema é particularmente valioso em domínios onde a precisão e a relevância da informação são críticas, e onde as necessidades do usuário podem evoluir ao longo do tempo.
#
# Enquanto a implementação adiciona complexidade em comparação com um sistema RAG básico, os benefícios em termos de qualidade de resposta e satisfação do usuário fazem dele um investimento de valor para aplicações que exigem recuperação e geração de informações de alta qualidade e consciente do contexto.

# %% [markdown]
# <div style="text-align: center;">
#
# <img src="../images/retrieval_with_feedback_loop.svg" alt="retrieval with feedback loop" style="width:40%; height:auto;">
# </div>

# %% [markdown]
# # Instalação e Importações do Pacote
# A célula abaixo instala todos os pacotes necessários para executar este notebook.
# .

# %%
# Install required packages
# !pip install langchain langchain-openai python-dotenv

# %%
# Clone the repository to access helper functions and evaluation modules
# !git clone https://github.com/NirDiamant/RAG_TECHNIQUES.git
import sys
sys.path.append('RAG_TECHNIQUES')
# If you need to run with the latest data
# !cp -r RAG_TECHNIQUES/data .

# %%
import os
import sys
from dotenv import load_dotenv
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import ChatOpenAI
from langchain.chains import RetrievalQA
import json
from typing import List, Dict, Any


# Original path append replaced for Colab compatibility
from helper_functions import *
from evaluation.evalute_rag import *

# Load environment variables from a .env file
load_dotenv()

# Set the OpenAI API key environment variable
os.environ["OPENAI_API_KEY"] = os.getenv('OPENAI_API_KEY')
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %% [markdown]
# ### Definir o caminho dos documentos

# %%
# Download required data files
import os
os.makedirs('data', exist_ok=True)

# Download the PDF document used in this notebook
# !wget -O data/Understanding_Climate_Change.pdf https://raw.githubusercontent.com/NirDiamant/RAG_TECHNIQUES/main/data/Understanding_Climate_Change.pdf
# !wget -O data/feedback_data.json https://raw.githubusercontent.com/NirDiamant/RAG_TECHNIQUES/main/data/feedback_data.json
# !wget -O data/Understanding_Climate_Change.pdf https://raw.githubusercontent.com/NirDiamant/RAG_TECHNIQUES/main/data/Understanding_Climate_Change.pdf

# %%
path = "data/Understanding_Climate_Change.pdf"

# %% [markdown]
# ### Criar a cadeia de armazenamento e recuperação de QA do vector

# %%
content = read_pdf_to_string(path)
vectorstore = encode_from_string(content)
retriever = vectorstore.as_retriever()

llm = ChatOpenAI(temperature=0, model_name="gpt-4o", max_tokens=4000)
qa_chain = RetrievalQA.from_chain_type(llm, retriever=retriever)

# %% [markdown]
# ### Função para formatar o feedback do usuário em um dicionário

# %%
def get_user_feedback(query, response, relevance, quality, comments=""):
    return {
        "query": query,
        "response": response,
        "relevance": int(relevance),
        "quality": int(quality),
        "comments": comments
    }

# %% [markdown]
# ## Função para armazenar o feedback em um arquivo json

# %%
def store_feedback(feedback):
    with open("data/feedback_data.json", "a") as f:
        json.dump(feedback, f)
        f.write("\n")

# %% [markdown]
# ## Função para ler o arquivo de feedback

# %%
def load_feedback_data():
    feedback_data = []
    try:
        with open("data/feedback_data.json", "r") as f:
            for line in f:
                feedback_data.append(json.loads(line.strip()))
    except FileNotFoundError:
        print("No feedback data file found. Starting with empty feedback.")
    return feedback_data

# %% [markdown]
# ### Função para ajustar a relevância dos arquivos com base no arquivo de feedbacks

# %%
class Response(BaseModel):
    answer: str = Field(..., title="The answer to the question. The options can be only 'Yes' or 'No'")

def adjust_relevance_scores(query: str, docs: List[Any], feedback_data: List[Dict[str, Any]]) -> List[Any]:
    # Create a prompt template for relevance checking
    relevance_prompt = PromptTemplate(
        input_variables=["query", "feedback_query", "doc_content", "feedback_response"],
        template="""
        Determine if the following feedback response is relevant to the current query and document content.
        You are also provided with the Feedback original query that was used to generate the feedback response.
        Current query: {query}
        Feedback query: {feedback_query}
        Document content: {doc_content}
        Feedback response: {feedback_response}
        
        Is this feedback relevant? Respond with only 'Yes' or 'No'.
        """
    )
    llm = ChatOpenAI(temperature=0, model_name="gpt-4o", max_tokens=4000)

    # Create an LLMChain for relevance checking
    relevance_chain = relevance_prompt | llm.with_structured_output(Response)

    for doc in docs:
        relevant_feedback = []
        
        for feedback in feedback_data:
            # Use LLM to check relevance
            input_data = {
                "query": query,
                "feedback_query": feedback['query'],
                "doc_content": doc.page_content[:1000],
                "feedback_response": feedback['response']
            }
            result = relevance_chain.invoke(input_data).answer
            
            if result == 'yes':
                relevant_feedback.append(feedback)
        
        # Adjust the relevance score based on feedback
        if relevant_feedback:
            avg_relevance = sum(f['relevance'] for f in relevant_feedback) / len(relevant_feedback)
            doc.metadata['relevance_score'] *= (avg_relevance / 3)  # Assuming a 1-5 scale, 3 is neutral
    
    # Re-rank documents based on adjusted scores
    return sorted(docs, key=lambda x: x.metadata['relevance_score'], reverse=True)

# %% [markdown]
# ### Função para ajustar o índice vetorial para incluir também consultas + respostas que receberam bons feedbacks

# %%
def fine_tune_index(feedback_data: List[Dict[str, Any]], texts: List[str]) -> Any:
    # Filter high-quality responses
    good_responses = [f for f in feedback_data if f['relevance'] >= 4 and f['quality'] >= 4]
    
    # Extract queries and responses, and create new documents
    additional_texts = []
    for f in good_responses:
        combined_text = f['query'] + " " + f['response']
        additional_texts.append(combined_text)

    # make the list a string
    additional_texts = " ".join(additional_texts)
    
    # Create a new index with original and high-quality texts
    all_texts = texts + additional_texts
    new_vectorstore = encode_from_string(all_texts)
    
    return new_vectorstore

# %% [markdown]
# ### Demonstração de como recuperar respostas em relação aos comentários do usuário

# %%
query = "What is the greenhouse effect?"

# Get response from RAG system
response = qa_chain(query)["result"]

relevance = 5
quality = 5

# Collect feedback
feedback = get_user_feedback(query, response, relevance, quality)

# Store feedback
store_feedback(feedback)

# Adjust relevance scores for future retrievals
docs = retriever.get_relevant_documents(query)
adjusted_docs = adjust_relevance_scores(query, docs, load_feedback_data())

# Update the retriever with adjusted docs
retriever.search_kwargs['k'] = len(adjusted_docs)
retriever.search_kwargs['docs'] = adjusted_docs

# %% [markdown]
# ### Finetune o vetorstore periodicamente

# %%
# Periodically (e.g., daily or weekly), fine-tune the index
new_vectorstore = fine_tune_index(load_feedback_data(), content)
retriever = new_vectorstore.as_retriever()

# %% [markdown]
# ![](https://europe-west1-rag-techniques-views-tracker.cloudfunctions.net/rag-techniques-tracker?notebook=all-rag-techniques--retrieval-with-feedback-loop)
